# %% [markdown]
# # RSLC to GSLC
# - This notebook converts NISAR RSLC data to GSLC and then RSLC data by running ISCE3's `gslc.py`.
# - Uses the `isce3_src` kernel (created using [Create_Environments.ipynb](https://github.com/isce-framework/sds-ondemand/blob/main/environments/Create_Environments.ipynb)).
# - Can be ran locally (preferably on a GPU instance), or as a PCM job.
#
# # Parameters
# This cell is marked `parameters`, indicating the variables within can substituted when running this notebook via `papermill`.
# - `data_link`: S3 url to the NISAR RSLC data to be converted into GSLC.
# - `dem_s3_url`: S3 url to the DEM file to download.
# - `gpu_enabled`: `1` to run using the GPU, `0` to use CPU instead. **Keep in mind that while disabling the GPU processing allows this notebook to be ran on an instance without a GPU, that does not guarantee the instance this notebook is running on is a non-GPU instance.** To run on a non-GPU instance on PCM, submit the job to a CPU-only queue.
# - `gslc_config`: The runconfig passed to `focus.py`.
#
# ### Upload parameters (PCM only)
# - `timestamp`: A time-string of the format `%Y%m%dT%H%M%S` indicating the time at which the job was submitted. This helps `pcm.py` find where the results of this job will be submitted when this notebook is ran as a PCM job.

# %%
data_link = 's3://nisar-st-data-ondemand/ALOS-1-data/RSLC/ALPSRP274410710-L1.0.h5' # string
dem_s3_url = 's3://nisar-st-data-ondemand/DEM-static/dem.tiff' # string
gpu_enabled = 1 # boolean
gslc_config = '' # string
timestamp = '20240131T0123456' # string

# hysds specifications
_time_limit = 86400
_soft_time_limit = 86400
_disk_usage = '10GB'
_submission_type = 'iteration'
_label = 'RSLC to GSLC PGE'

# %% [markdown]
# ### Pre-processing of the Parameters to convert numbers or words into `boolean` True and False values.

# %%
# Convert boolean parameters because they must be specified as strings
try:
    if not isinstance(gpu_enabled, bool):
        gpu_enabled = int(gpu_enabled) > 0
except ValueError:
    if instance(gpu_enabled, str):
        gpu_enabled = gpu_enabled.lower() == 'true'
    else:
        gpu_enabled = False
print(f'{gpu_enabled=}')

# Extraneous parameters
focus_config = '' # string
insar_config = '' # string
# Out:
# gpu_enabled=True

# %% [markdown]
# # Functions for loading runconfig files and downloading from S3 buckets

# %%
import os
import yaml
import asf_search as asf
import boto3
import aws_uploader

WORKING_DIR = os.getcwd()
HOME_DIR = os.environ['HOME']
NOTEBOOK_PGE_DIR = os.environ.get('NOTEBOOK_PGE_DIR', WORKING_DIR)
ISCE3_BUILD_DIR = os.environ.get('ISCE3_BUILD_DIR', f'{HOME_DIR}/isce3/build')

DOWNLOAD_DIR = os.path.join(WORKING_DIR, 'downloads')
EXTRACT_DIR = os.path.join(WORKING_DIR, 'alos_data')
OUTPUT_DIR = os.path.join(WORKING_DIR, 'output')
PRODUCT_DIR = os.path.join(WORKING_DIR, 'product_path')

os.makedirs(DOWNLOAD_DIR, exist_ok=True)
os.makedirs(EXTRACT_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

# RSLC
if focus_config == '':
    with open(os.path.join(NOTEBOOK_PGE_DIR, '../templates/focus.yaml'), 'r') as f:
        FOCUS_YML = yaml.safe_load(f)
else:
    print('Using custom focus.py run config...')
    FOCUS_YML = yaml.safe_load(focus_config)
    
# GSLC
if gslc_config == '':
    with open(os.path.join(NOTEBOOK_PGE_DIR, '../templates/gslc.yaml'), 'r') as f:
        GSLC_YML = yaml.safe_load(f)
else:
    print('Using custom gslc.py run config...')
    GSLC_YML = yaml.safe_load(gslc_config)

# INSAR
if insar_config == '':
    with open(os.path.join(NOTEBOOK_PGE_DIR, '../templates/insar.yaml'), 'r') as f:
        INSAR_YML = yaml.safe_load(f)
else:
    print('Using custom insar.py run config...')
    INSAR_YML = yaml.safe_load(insar_config)

print(WORKING_DIR)
# Out:
# /home/jovyan/alos-to-insar/notebook_pges

# %% [markdown]
# # Run ISCE3 Python Scripts
# This cell runs the python scripts:
# - `gslc.py`: Converts NISAR RSLC -> GSLC

# %%
from urllib.parse import urlparse
import isce3_config

# Download the specified L0B data
target_path = os.path.join(DOWNLOAD_DIR, os.path.basename(urlparse(data_link).path))
if not os.path.exists(target_path):
    print(f'Downloading {target_path} from S3 bucket at {data_link}...')
    aws_uploader.AWS.download_s3(data_link, target_path)
else:
    print(f'{target_path} already exists, skipping download...')

# Download the DEM locally
dem_f = isce3_config.download_dem(dem_s3_url, DOWNLOAD_DIR)

# Run gslc.py
yml_path = os.path.join(OUTPUT_DIR, 'gslc_final.yaml')
output_name = os.path.basename(os.path.splitext(target_path)[0])
output_f = os.path.join(PRODUCT_DIR, f'{output_name}_GSLC.h5')
isce3_config.write_gslc_config(GSLC_YML, target_path, dem_f, yml_path, gpu_enabled, output_f)
print(f'Executing:\n    mamba run -n isce3_src python {ISCE3_BUILD_DIR}/packages/nisar/workflows/gslc.py {yml_path} --no-log')
# !mamba run -n isce3_src python {ISCE3_BUILD_DIR}/packages/nisar/workflows/gslc.py {yml_path} --no-log
# Out:
# /home/jovyan/alos-to-insar/notebook_pges/downloads/ALPSRP274410710-L1.0.h5 already exists, skipping download...
# /home/jovyan/alos-to-insar/notebook_pges/downloads/dem.tiff already exists, skipping download...
# Downloaded DEM: /home/jovyan/alos-to-insar/notebook_pges/downloads/dem.tiff
# Executing:
#     mamba run -n isce3_src python /home/jovyan/isce3/build/packages/nisar/workflows/gslc.py /home/jovyan/alos-to-insar/notebook_pges/output/gslc_final.yaml --no-log
# journal: preparing HDF5
# journal: successfully ran h5_prep
# journal: starting geocode SLC
# journal: running geocode SLC array block 1 of 130
# journal: no radar data found for block 1 of 130
# journal: running geocode SLC array block 14 of 130
# journal: no radar data found for block 14 of 130
# journal: running geocode SLC array block 27 of 130
# journal: no radar data found for block 27 of 130
# journal: running geocode SLC array block 40 of 130
# journal: no radar data found for block 40 of 130
# journal: running geocode SLC array block 53 of 130
# journal: no radar data found for block 53 of 130
# journal: running geocode SLC array block 66 of 130
# journal: no radar data found for block 66 of 130
# journal: running geocode SLC array block 79 of 130
# journal: no radar data found for block 79 of 130
# journal: running geocode SLC array block 92 of 130
# journal: no radar data found for block 92 of 130
# journal: running geocode SLC array block 105 of 130
# journal: no radar data found for block 105 of 130
# journal: running geocode SLC array block 118 of 130
# journal: no radar data found for block 118 of 130
# journal: running geocode SLC array block 2 of 130
# journal: no radar data found for block 2 of 130
# journal: running geocode SLC array block 15 of 130
# journal: no radar data found for block 15 of 130
# journal: running geocode SLC array block 28 of 130
# journal: no radar data found for block 28 of 130
# journal: running geocode SLC array block 41 of 130
# journal: no radar data found for block 41 of 130
# journal: running geocode SLC array block 54 of 130
# journal: no radar data found for block 54 of 130
# journal: running geocode SLC array block 67 of 130
# journal: no radar data found for block 67 of 130
# journal: running geocode SLC array block 80 of 130
# journal: no radar data found for block 80 of 130
# journal: running geocode SLC array block 93 of 130
# journal: no radar data found for block 93 of 130
# journal: running geocode SLC array block 106 of 130
# journal: no radar data found for block 106 of 130
# journal: running geocode SLC array block 119 of 130
# journal: no radar data found for block 119 of 130
# journal: running geocode SLC array block 3 of 130
# journal: no radar data found for block 3 of 130
# journal: running geocode SLC array block 16 of 130
# journal: no radar data found for block 16 of 130
# journal: running geocode SLC array block 29 of 130
# journal: no radar data found for block 29 of 130
# journal: running geocode SLC array block 42 of 130
# journal: no radar data found for block 42 of 130
# journal: running geocode SLC array block 55 of 130
# journal: no radar data found for block 55 of 130
# journal: running geocode SLC array block 68 of 130
# journal: no radar data found for block 68 of 130
# journal: running geocode SLC array block 81 of 130
# journal: no radar data found for block 81 of 130
# journal: running geocode SLC array block 94 of 130
# journal: no radar data found for block 94 of 130
# journal: running geocode SLC array block 107 of 130
# journal: no radar data found for block 107 of 130
# journal: running geocode SLC array block 120 of 130
# journal: no radar data found for block 120 of 130
# journal: running geocode SLC array block 4 of 130
# journal: no radar data found for block 4 of 130
# journal: running geocode SLC array block 17 of 130
# journal: no radar data found for block 17 of 130
# journal: running geocode SLC array block 30 of 130
# journal: no radar data found for block 30 of 130
# journal: running geocode SLC array block 43 of 130
# journal: no radar data found for block 43 of 130
# journal: running geocode SLC array block 56 of 130
# journal: no radar data found for block 56 of 130
# journal: running geocode SLC array block 69 of 130
# journal: no radar data found for block 69 of 130
# journal: running geocode SLC array block 82 of 130
# journal: no radar data found for block 82 of 130
# journal: running geocode SLC array block 95 of 130
# journal: no radar data found for block 95 of 130
# journal: running geocode SLC array block 108 of 130
# journal: no radar data found for block 108 of 130
# journal: running geocode SLC array block 121 of 130
# journal: no radar data found for block 121 of 130
# journal: running geocode SLC array block 5 of 130
# journal: no radar data found for block 5 of 130
# journal: running geocode SLC array block 18 of 130
# journal: no radar data found for block 18 of 130
# journal: running geocode SLC array block 31 of 130
# journal: no radar data found for block 31 of 130
# journal: running geocode SLC array block 44 of 130
# journal: no radar data found for block 44 of 130
# journal: running geocode SLC array block 57 of 130
# journal: no radar data found for block 57 of 130
# journal: running geocode SLC array block 70 of 130
# journal: no radar data found for block 70 of 130
# journal: running geocode SLC array block 83 of 130
# journal: no radar data found for block 83 of 130
# journal: running geocode SLC array block 96 of 130
# journal: no radar data found for block 96 of 130
# journal: running geocode SLC array block 109 of 130
# journal: no radar data found for block 109 of 130
# journal: running geocode SLC array block 122 of 130
# journal: no radar data found for block 122 of 130
# journal: running geocode SLC array block 6 of 130
# journal: no radar data found for block 6 of 130
# journal: running geocode SLC array block 19 of 130
# journal: no radar data found for block 19 of 130
# journal: running geocode SLC array block 32 of 130
# journal: no radar data found for block 32 of 130
# journal: running geocode SLC array block 45 of 130
# journal: no radar data found for block 45 of 130
# journal: running geocode SLC array block 58 of 130
# journal: no radar data found for block 58 of 130
# journal: running geocode SLC array block 71 of 130
# journal: no radar data found for block 71 of 130
# journal: running geocode SLC array block 84 of 130
# journal: no radar data found for block 84 of 130
# journal: running geocode SLC array block 97 of 130
# journal: no radar data found for block 97 of 130
# journal: running geocode SLC array block 110 of 130
# journal: no radar data found for block 110 of 130
# journal: running geocode SLC array block 123 of 130
# journal: no radar data found for block 123 of 130
# journal: running geocode SLC array block 7 of 130
# journal: no radar data found for block 7 of 130
# journal: running geocode SLC array block 20 of 130
# journal: no radar data found for block 20 of 130
# journal: running geocode SLC array block 33 of 130
# journal: no radar data found for block 33 of 130
# journal: running geocode SLC array block 46 of 130
# journal: no radar data found for block 46 of 130
# journal: running geocode SLC array block 59 of 130
# journal: no radar data found for block 59 of 130
# journal: running geocode SLC array block 72 of 130
# journal: no radar data found for block 72 of 130
# journal: running geocode SLC array block 85 of 130
# journal: no radar data found for block 85 of 130
# journal: running geocode SLC array block 98 of 130
# journal: no radar data found for block 98 of 130
# journal: running geocode SLC array block 111 of 130
# journal: no radar data found for block 111 of 130
# journal: running geocode SLC array block 124 of 130
# journal: no radar data found for block 124 of 130
# journal: running geocode SLC array block 8 of 130
# journal: no radar data found for block 8 of 130
# journal: running geocode SLC array block 21 of 130
# journal: no radar data found for block 21 of 130
# journal: running geocode SLC array block 34 of 130
# journal: no radar data found for block 34 of 130
# journal: running geocode SLC array block 47 of 130
# journal: no radar data found for block 47 of 130
# journal: running geocode SLC array block 60 of 130
# journal: no radar data found for block 60 of 130
# journal: running geocode SLC array block 73 of 130
# journal: no radar data found for block 73 of 130
# journal: running geocode SLC array block 86 of 130
# journal: no radar data found for block 86 of 130
# journal: running geocode SLC array block 99 of 130
# journal: no radar data found for block 99 of 130
# journal: running geocode SLC array block 112 of 130
# journal: no radar data found for block 112 of 130
# journal: running geocode SLC array block 125 of 130
# journal: no radar data found for block 125 of 130
# journal: running geocode SLC array block 9 of 130
# journal: no radar data found for block 9 of 130
# journal: running geocode SLC array block 22 of 130
# journal: no radar data found for block 22 of 130
# journal: running geocode SLC array block 35 of 130
# journal: no radar data found for block 35 of 130
# journal: running geocode SLC array block 48 of 130
# journal: no radar data found for block 48 of 130
# journal: running geocode SLC array block 61 of 130
# journal: no radar data found for block 61 of 130
# journal: running geocode SLC array block 74 of 130
# journal: no radar data found for block 74 of 130
# journal: running geocode SLC array block 87 of 130
# journal: no radar data found for block 87 of 130
# journal: running geocode SLC array block 100 of 130
# journal: no radar data found for block 100 of 130
# journal: running geocode SLC array block 113 of 130
# journal: no radar data found for block 113 of 130
# journal: running geocode SLC array block 126 of 130
# journal: no radar data found for block 126 of 130
# journal: running geocode SLC array block 10 of 130
# journal: no radar data found for block 10 of 130
# journal: running geocode SLC array block 23 of 130
# journal: no radar data found for block 23 of 130
# journal: running geocode SLC array block 36 of 130
# journal: no radar data found for block 36 of 130
# journal: running geocode SLC array block 49 of 130
# journal: no radar data found for block 49 of 130
# journal: running geocode SLC array block 62 of 130
# journal: no radar data found for block 62 of 130
# journal: running geocode SLC array block 75 of 130
# journal: no radar data found for block 75 of 130
# journal: running geocode SLC array block 88 of 130
# journal: no radar data found for block 88 of 130
# journal: running geocode SLC array block 101 of 130
# journal: no radar data found for block 101 of 130
# journal: running geocode SLC array block 114 of 130
# journal: no radar data found for block 114 of 130
# journal: running geocode SLC array block 127 of 130
# journal: no radar data found for block 127 of 130
# journal: running geocode SLC array block 11 of 130
# journal: no radar data found for block 11 of 130
# journal: running geocode SLC array block 24 of 130
# journal: no radar data found for block 24 of 130
# journal: running geocode SLC array block 37 of 130
# journal: no radar data found for block 37 of 130
# journal: running geocode SLC array block 50 of 130
# journal: no radar data found for block 50 of 130
# journal: running geocode SLC array block 63 of 130
# journal: no radar data found for block 63 of 130
# journal: running geocode SLC array block 76 of 130
# journal: no radar data found for block 76 of 130
# journal: running geocode SLC array block 89 of 130
# journal: no radar data found for block 89 of 130
# journal: running geocode SLC array block 102 of 130
# journal: no radar data found for block 102 of 130
# journal: running geocode SLC array block 115 of 130
# journal: no radar data found for block 115 of 130
# journal: running geocode SLC array block 128 of 130
# journal: no radar data found for block 128 of 130
# journal: running geocode SLC array block 12 of 130
# journal: no radar data found for block 12 of 130
# journal: running geocode SLC array block 25 of 130
# journal: no radar data found for block 25 of 130
# journal: running geocode SLC array block 38 of 130
# journal: no radar data found for block 38 of 130
# journal: running geocode SLC array block 51 of 130
# journal: no radar data found for block 51 of 130
# journal: running geocode SLC array block 64 of 130
# journal: no radar data found for block 64 of 130
# journal: running geocode SLC array block 77 of 130
# journal: no radar data found for block 77 of 130
# journal: running geocode SLC array block 90 of 130
# journal: no radar data found for block 90 of 130
# journal: running geocode SLC array block 103 of 130
# journal: no radar data found for block 103 of 130
# journal: running geocode SLC array block 116 of 130
# journal: no radar data found for block 116 of 130
# journal: running geocode SLC array block 129 of 130
# journal: no radar data found for block 129 of 130
# journal: running geocode SLC array block 13 of 130
# journal: no radar data found for block 13 of 130
# journal: running geocode SLC array block 26 of 130
# journal: no radar data found for block 26 of 130
# journal: running geocode SLC array block 39 of 130
# journal: no radar data found for block 39 of 130
# journal: running geocode SLC array block 52 of 130
# journal: no radar data found for block 52 of 130
# journal: running geocode SLC array block 65 of 130
# journal: no radar data found for block 65 of 130
# journal: running geocode SLC array block 78 of 130
# journal: no radar data found for block 78 of 130
# journal: running geocode SLC array block 91 of 130
# journal: no radar data found for block 91 of 130
# journal: running geocode SLC array block 104 of 130
# journal: no radar data found for block 104 of 130
# journal: running geocode SLC array block 117 of 130
# journal: no radar data found for block 117 of 130
# journal: running geocode SLC array block 130 of 130
# journal: no radar data found for block 130 of 130
# journal: successfully ran geocode SLC in 5.846 seconds
# journal: nbands: 1
# journal:
#  -- array length: 24879
#  -- array width: 9090
#  -- number of block(s): 8
#  -- block length: 3110
#  -- block width: 9090
#  -- block size: 216MB
# journal: processing band: 1
# journal:
#  -- band: 1
#  --     n. valid: 226150110 (100%)
#  --     min (real): 0, mean (real): 0, max (real): 0, sample stddev (real): 0
#  --     min (imag): 0, mean (imag): 0, max (imag): 0, sample stddev (imag): 0
# journal:
#  -- cube height: 21
#  -- cube length: 205
#  -- cube width: 188
# journal: EPSG: 32611
# journal:
#  -- start X: 127458.271780
#  -- end X: 221458.271780
#  -- start Y: 4059101.906279
#  -- end Y: 3956601.906279
#  -- spacing X: 500.000000
#  -- spacing Y: -500.000000
#  -- width: 188
#  -- length: 205
#  -- epsg: 32611
#
# WARNING: overwriting environment variables set in the machine
# overwriting variable {'LD_LIBRARY_PATH'}
# /home/jovyan/isce3/build/packages/nisar/workflows/h5_prep.py:207: UserWarning: swmr=True only affects read ('r') mode. For swmr write mode, set f.swmr_mode = True after opening the file.
#   h5py.File(output_hdf5, 'w', libver='latest', swmr=True) as dst_h5:
# /home/jovyan/isce3/build/packages/nisar/workflows/h5_prep.py:500: UserWarning: swmr=True only affects read ('r') mode. For swmr write mode, set f.swmr_mode = True after opening the file.
#   with h5py.File(output_hdf5, 'a', libver='latest', swmr=True) as dst_h5:

# %% [markdown]
# # Automatic Stage Out for PCM Jobs
# This routine creates a folder which matches the regex:
#
# #### GSLC
# **Example:** `NISAR_L2_PR_GSLC_000_000_Z_000_0000_HH_20240131T000000_20250131T000000_0A1B2C_A_F_0000`
# ```
# (?P<id>NISAR_L2_(?P<processing_type>[P|U]R)_GSLC_(?P<cycle_number>\d{3})_(?P<relative_orbit_number>\d{3})_(?P<Direction>\w)_(?P<TrackFrame>\d{3})_(?P<radar_processing_mode>\d{4})_(?P<Polarization>\w{2})_(?P<RadarStartDateTime>(?P<year>\d{4})(?P<month>\d{2})(?P<day>\d{2})T\d{6})_(?P<RadarStopDateTime>\d{8}T\d{6})_(?P<composite_release_id>\w{6})_(?P<Fidelity>\w)_(?P<CoverageIndicator>[F|P])_(?P<product_counter>\d{3}))$
# ```
# This enables PCM to automatically upload the results of this notebook to the `s3://nisar-{system_name}-rs-ondemand` bucket.
#
# `system_name` is one of the following:
# - `st` (for Science Team)
# - `adt` (for ADT)
# - `iot` (for IOT)

# %%
import h5py
import json

# Grab some appropriate values for PCM to automatically stage out
polarization = 'HH'
regex_name = isce3_config.GSLC_FORMAT.format(
    polarization=polarization,
    timestamp=timestamp)
auto_output_dir = os.path.join(WORKING_DIR, regex_name)

# Create the automatic stage-out directory
# !mkdir -p {auto_output_dir}
# !cp {WORKING_DIR}/*-output.ipynb {auto_output_dir}
# !cp {WORKING_DIR}/*.txt {auto_output_dir} 
# !cp {WORKING_DIR}/*.json {auto_output_dir}
# !mv {yml_path} {auto_output_dir}
# !mv {output_f} {auto_output_dir}

# Move the new path variables to avoid confusion
yml_path = os.path.join(auto_output_dir, os.path.basename(yml_path))
output_f = os.path.join(auto_output_dir, os.path.basename(output_f))

# Create metadata files for the automatic stage-out directory
with open(os.path.join(auto_output_dir, f'{regex_name}.met.json'), 'w', encoding='utf-8') as f:
    content = {
        'polarization': polarization,
    }
    f.write(json.dumps(content))
with open(os.path.join(auto_output_dir, f'{regex_name}.dataset.json'), 'w', encoding='utf-8') as f:
    content = {
         'version': 'v1.0',
         'label': 'This is purely an EXAMPLE metadata file, the values in this file are not representative of this product.',
         'location': {
           'type': 'polygon',
           'coordinates': [
             [
                [-122.9059682940358,40.47090915967475],
                [-121.6679748715316,37.84406528996276],
                [-120.7310161872557,38.28728069813177],
                [-121.7043611684245,39.94137004454238],
                [-121.9536916840953,40.67097860759095],
                [-122.3100379696548,40.7267890636145],
                [-122.7640648263371,40.5457010812299],
                [-122.9059682940358,40.47090915967475]
              ]
            ]
        },
        'starttime': '2017-01-01T00:00:00',
        'endtime': '2017-01-01T00:05:00',
    }
    f.write(json.dumps(content))
# Out:
# cp: cannot stat ‘/home/jovyan/alos-to-insar/notebook_pges/*-output.ipynb’: No such file or directory
# cp: cannot stat ‘/home/jovyan/alos-to-insar/notebook_pges/*.txt’: No such file or directory
# cp: cannot stat ‘/home/jovyan/alos-to-insar/notebook_pges/*.json’: No such file or directory
